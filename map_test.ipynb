# %%
import folium

# %%
map_osm = folium.Map(location=[38.993841, -77.031321], tiles='Stamen Toner',
           zoom_start=15)
folium.Marker([38.993841, -77.031321], popup='Silver Spring', 
              icon=folium.Icon(color='green')).add_to(map_osm)
folium.Marker([38.99521, -77.02918], popup='Silver Spring Metro/Colesville Rd & Wayne Ave', 
              icon=folium.Icon(color='red')).add_to(map_osm)
map_osm
#map_osm.save('/tmp/map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map_osm.save('map.html')
